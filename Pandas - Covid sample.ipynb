# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline
import wget

# %%
urls = [
    'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv',
    'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv',
    'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv'
]

# %% [markdown]
# # Download files directly from URLs using wget

# %%
# [wget.download(url) for url in urls]

# %% [markdown]
# # read data from csv using pandas

# %%
df_cnfmd=pd.read_csv('time_series_covid19_confirmed_global.csv')
df_dth=pd.read_csv('time_series_covid19_deaths_global.csv')
df_rcvrd=pd.read_csv('time_series_covid19_recovered_global.csv')

# %% [markdown]
# # print data frame

# %%
df_cnfmd
# Out:
#     Province/State         Country/Region        Lat       Long  1/22/20  \
# 0              NaN            Afghanistan  33.939110  67.709953        0
# 1              NaN                Albania  41.153300  20.168300        0
# 2              NaN                Algeria  28.033900   1.659600        0
# 3              NaN                Andorra  42.506300   1.521800        0
# 4              NaN                 Angola -11.202700  17.873900        0
# ..             ...                    ...        ...        ...      ...
# 261            NaN  Sao Tome and Principe   0.186400   6.613100        0
# 262            NaN                  Yemen  15.552727  48.516388        0
# 263            NaN                Comoros -11.645500  43.333300        0
# 264            NaN             Tajikistan  38.861000  71.276100        0
# 265            NaN                Lesotho -29.610000  28.233600        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  7/13/20  7/14/20  \
# ...

# %% [markdown]
# # Return first n rows from the data frame; default 5

# %%
df_cnfmd.head(5)
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  7/13/20  7/14/20  7/15/20  \
# 0        0        0        0        0  ...    34455    34740    34994
# 1        0        0        0        0  ...     3571     3667     3752
# 2        0        0        0        0  ...    19689    20216    20770
# 3        0        0        0        0  ...      858      861      862
# 4        0        0        0        0  ...      525      541      576
#
#    7/16/20  7/17/20  7/18/20  7/19/20  7/20/20  7/21/20  7/22/20
# ...

# %% [markdown]
# # Access single element in a row such as country name

# %%
df_cnfmd['Country/Region'].iloc[0]
# Out:
# 'Afghanistan'

# %% [markdown]
# # Access full column information

# %%
df_cnfmd['Country/Region']
# Out:
# 0                Afghanistan
# 1                    Albania
# 2                    Algeria
# 3                    Andorra
# 4                     Angola
#                ...
# 261    Sao Tome and Principe
# 262                    Yemen
# 263                  Comoros
# 264               Tajikistan
# 265                  Lesotho
# Name: Country/Region, Length: 266, dtype: object

# %% [markdown]
# # Get total count of countries i.e. count of Rows

# %%
df_cnfmd['Country/Region'].count()
# Out:
# 266

# %%
#df_cnfmd['Province/State']='NaN'

# %% [markdown]
# # Conditional check for numeric value such as count greater than 0

# %%
df_cnfmd[df_cnfmd['1/22/20']>0].head()
# Out:
#    Province/State Country/Region      Lat      Long  1/22/20  1/23/20  \
# 49          Anhui          China  31.8257  117.2264        1        9
# 50        Beijing          China  40.1824  116.4142       14       22
# 51      Chongqing          China  30.0572  107.8740        6        9
# 52         Fujian          China  26.0789  117.9874        1        5
# 54      Guangdong          China  23.3417  113.4244       26       32
#
#     1/24/20  1/25/20  1/26/20  1/27/20  ...  7/13/20  7/14/20  7/15/20  \
# 49       15       39       60       70  ...      991      991      991
# 50       36       41       68       80  ...      929      929      929
# 51       27       57       75      110  ...      582      583      583
# 52       10       18       35       59  ...      363      363      363
# 54       53       78      111      151  ...     1650     1650     1650
#
#     7/16/20  7/17/20  7/18/20  7/19/20  7/20/20  7/21/20  7/22/20
# ...

# %% [markdown]
# # Extracting the data from data frame and cleaning it

# %%
df_Only_Aus=df_cnfmd[(df_cnfmd['Province/State']=='Queensland')]

# %%
df_Only_Aus # Displaying data in the row format
# Out:
#    Province/State Country/Region      Lat      Long  1/22/20  1/23/20  \
# 11     Queensland      Australia -27.4698  153.0251        0        0
#
#     1/24/20  1/25/20  1/26/20  1/27/20  ...  7/13/20  7/14/20  7/15/20  \
# 11        0        0        0        0  ...     1071     1071     1071
#
#     7/16/20  7/17/20  7/18/20  7/19/20  7/20/20  7/21/20  7/22/20
# 11     1071     1071     1071     1072     1072     1073     1074
#
# [1 rows x 187 columns]

# %%
df_Only_Aus=df_Only_Aus.reset_index()  # Reset index

# %%
df_Only_Aus=df_Only_Aus.transpose() # transpose it to Columnwise

# %%
df_Only_Aus
# Out:
#                          0
# index                   11
# Province/State  Queensland
# Country/Region   Australia
# Lat               -27.4698
# Long               153.025
# ...                    ...
# 7/18/20               1071
# 7/19/20               1072
# 7/20/20               1072
# 7/21/20               1073
# 7/22/20               1074
#
# [188 rows x 1 columns]

# %%
df_Only_Aus =df_Only_Aus.drop(['Long','Lat','Province/State','Country/Region','index'],axis=0) # Droping the data from Rows

# %%
df_Only_Aus
# Out:
#             0
# 1/22/20     0
# 1/23/20     0
# 1/24/20     0
# 1/25/20     0
# 1/26/20     0
# ...       ...
# 7/18/20  1071
# 7/19/20  1072
# 7/20/20  1072
# 7/21/20  1073
# 7/22/20  1074
#
# [183 rows x 1 columns]

# %%
df_Only_Aus.rename(columns={0:'Australia'}, inplace=True) #Renaming the column 0 with country name

# %%
df_Only_Aus
# Out:
#         Australia
# 1/22/20         0
# 1/23/20         0
# 1/24/20         0
# 1/25/20         0
# 1/26/20         0
# ...           ...
# 7/18/20      1071
# 7/19/20      1072
# 7/20/20      1072
# 7/21/20      1073
# 7/22/20      1074
#
# [183 rows x 1 columns]

# %%
df_Only_Aus.plot() #Simple line plot

# %% [markdown]
# # Cleaning data for more than one column

# %%
df_Australia=df_cnfmd[(df_cnfmd['Country/Region']=='Australia')]

# %%
df_Australia
# Out:
#         Australian Capital Territory New South Wales Northern Territory  \
# 1/22/20                            0               0                  0
# 1/23/20                            0               0                  0
# 1/24/20                            0               0                  0
# 1/25/20                            0               0                  0
# 1/26/20                            0               3                  0
# ...                              ...             ...                ...
# 7/18/20                          113            3568                 31
# 7/19/20                          113            3588                 31
# 7/20/20                          113            3599                 31
# 7/21/20                          113            3614                 31
# 7/22/20                          113            3633                 31
#
#         Queensland South Australia Tasmania Victoria Western Australia
# ...

# %%
df_Australia=df_Australia.drop(['Country/Region','Lat','Long'],axis=1)

# %% [markdown]
# # Reset Index

# %%
df_Australia=df_Australia.reset_index()

# %% [markdown]
# # Transpose

# %%
df_Australia=df_Australia.transpose()

# %% [markdown]
# # Retrieve data from row

# %%
# df_Australia.loc['Province/State']

# %%
ls=df_Australia.loc['Province/State']

# %% [markdown]
# # Rename Column

# %%
for i,prov in enumerate(ls):
    df_Australia.rename(columns={i:prov}, inplace=True)

# %%
df_Australia=df_Australia.drop(['index','Province/State'],axis=0)

# %%
df_Australia.plot()

# %%
df_Australia
# Out:
#         Australian Capital Territory New South Wales Northern Territory  \
# 1/22/20                            0               0                  0
# 1/23/20                            0               0                  0
# 1/24/20                            0               0                  0
# 1/25/20                            0               0                  0
# 1/26/20                            0               3                  0
# ...                              ...             ...                ...
# 7/18/20                          113            3568                 31
# 7/19/20                          113            3588                 31
# 7/20/20                          113            3599                 31
# 7/21/20                          113            3614                 31
# 7/22/20                          113            3633                 31
#
#         Queensland South Australia Tasmania Victoria Western Australia
# ...

# %%
df_Australia>1500
# Out:
# 1/22/20    False
# 1/23/20    False
# 1/24/20    False
# 1/25/20    False
# 1/26/20    False
#            ...
# 7/18/20    False
# 7/19/20    False
# 7/20/20    False
# 7/21/20    False
# 7/22/20    False
# Name: Queensland, Length: 183, dtype: bool

# %% [markdown]
# # Seaborn

# %%
sns.distplot(df_Australia.loc['1/26/20'],kde=False,bins =30)

# %%
df_Australia.loc['1/26/20']
# Out:
# Australian Capital Territory    0
# New South Wales                 3
# Northern Territory              0
# Queensland                      0
# South Australia                 0
# Tasmania                        0
# Victoria                        1
# Western Australia               0
# Name: 1/26/20, dtype: object

# %%
df_Australia['Western Australia']!=0
# Out:
# 1/22/20    False
# 1/23/20    False
# 1/24/20    False
# 1/25/20    False
# 1/26/20    False
#            ...
# 7/18/20     True
# 7/19/20     True
# 7/20/20     True
# 7/21/20     True
# 7/22/20     True
# Name: Western Australia, Length: 183, dtype: bool

# %%
sns.jointplot(data=df_Australia)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-d5221a6d5b15> in <module>
# ----> 1 sns.jointplot(data=df_Australia)
#
# TypeError: jointplot() missing 2 required positional arguments: 'x' and 'y'

# %% [markdown]
# # Combining two conditions

# %%
srs_cnfmd=df_cnfmd[(df_cnfmd['Country/Region']=='China') & (df_cnfmd['Province/State']=='Beijing')]

# %%
type(srs_cnfmd)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df_cnfmd['Province/State'])
# Out:
# pandas.core.series.Series

# %%
df_cnfmd[(df_cnfmd['1/22/20']>0) & (df_cnfmd['Country/Region']!='China')][['Country/Region','1/22/20']]
# Out:
#     Country/Region  1/22/20
# 139          Japan        2
# 143   Korea, South        1
# 207        Taiwan*        1
# 209       Thailand        2
# 225             US        1

# %%
df_cnfmd[(df_cnfmd['1/22/20']>0) & (df_cnfmd['Country/Region']!='China')][['Country/Region','1/22/20']]
# Out:
#     Country/Region  1/22/20
# 139          Japan        2
# 143   Korea, South        1
# 207        Taiwan*        1
# 209       Thailand        2
# 225             US        1

# %%
df_cnfmd.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  7/13/20  7/14/20  7/15/20  \
# 0        0        0        0        0  ...    34455    34740    34994
# 1        0        0        0        0  ...     3571     3667     3752
# 2        0        0        0        0  ...    19689    20216    20770
# 3        0        0        0        0  ...      858      861      862
# 4        0        0        0        0  ...      525      541      576
#
#    7/16/20  7/17/20  7/18/20  7/19/20  7/20/20  7/21/20  7/22/20
# ...
