# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline
import wget

# %% [markdown]
# # # Temporary example of plotting Company performance for 4 months

# %%
from numpy.random import randn

# %%
# Collecting real numbers like +ve and -ve

# %%
arrRealNum64=randn(4,6)

# %%
arrRealNum64
# Out:
# array([[-0.44868855, -2.00366942,  2.20292591,  0.26698247,  1.2056628 ,
#         -0.42686197],
#        [-1.01366474, -1.4814377 ,  0.90587052,  0.61279904,  1.19426175,
#          0.29428986],
#        [ 0.19926221, -0.36724674, -0.13037312, -0.23506168, -0.21029038,
#         -2.13249104],
#        [ 1.78131933,  1.14425969, -0.81634315, -0.36027358, -0.99733798,
#          0.18197821]])

# %%
# Collecting all + ve and numbers with in range

# %%
arrNum64=np.random.randint(0,10,size=(6,4))

# %%
arrNum64
# Out:
# array([[1, 4, 3, 2],
#        [9, 7, 6, 3],
#        [9, 8, 6, 1],
#        [0, 2, 5, 7],
#        [3, 7, 8, 9],
#        [2, 1, 7, 7]])

# %%
arrNum46=arrNum64.reshape(4,6)

# %%
arrNum46
# Out:
# array([[1, 4, 3, 2, 9, 7],
#        [6, 3, 9, 8, 6, 1],
#        [0, 2, 5, 7, 3, 7],
#        [8, 9, 2, 1, 7, 7]])

# %%
df=pd.DataFrame(arrNum46,['Jun','Jul','Aug','Sep'],['Apple','Blueberry','Mango','Cherry','Grapes','Strawberries'])

# %% [markdown]
# # Plot full data frame

# %%
df.plot()

# %%
df
# Out:
#      Apple  Blueberry  Mango  Cherry  Grapes  Strawberries
# Jun      1          4      3       2       9             7
# Jul      6          3      9       8       6             1
# Aug      0          2      5       7       3             7
# Sep      8          9      2       1       7             7

# %% [markdown]
# # Plotting DataFrame with Conditions

# %%
tempdf=df[df>3]

# %%
tempdfm=tempdf.fillna(1)

# %%
tempdfm.plot()

# %%
tempdf.plot(kind='area')

# %%
tempdfm
# Out:
#      Apple  Blueberry  Mango  Cherry  Grapes  Strawberries
# Jun    1.0        4.0    1.0     1.0     9.0           7.0
# Jul    6.0        1.0    9.0     8.0     6.0           1.0
# Aug    1.0        1.0    5.0     7.0     1.0           7.0
# Sep    8.0        9.0    1.0     1.0     7.0           7.0

# %% [markdown]
# # # # Plotting a Series from data frame

# %%
appleData=df['Apple']

# %%
appleData
# Out:
# Jun    1
# Jul    6
# Aug    0
# Sep    8
# Name: Apple, dtype: int32

# %%
type(appleData)
# Out:
# pandas.core.series.Series

# %%
appleData.plot(kind='pie')

# %%
appleData.plot(kind='area')

# %% [markdown]
# # Plotting same dataframe Monthwise

# %%
# df1=pd.DataFrame(arrNum64,['Apple','Blueberry','Mango','Cherry','Grapes','Strawberries'],['Jun','Jul','Aug','Sep'])

# %%
# df1

# %%
# df1.plot()

# %%
df_cnfmd[df_cnfmd['1/22/20']>0][['Country/Region','1/22/20']].plot()

# %%
df_cnfmd[(df_cnfmd['1/22/20']>0) & (df_cnfmd['Country/Region']!='China')][['Country/Region','1/22/20']]
# Out:
#     Country/Region  1/22/20
# 139          Japan        2
# 143   Korea, South        1
# 207        Taiwan*        1
# 209       Thailand        2
# 225             US        1

# %%
df_cnfmd[(df_cnfmd['1/22/20']>0) & (df_cnfmd['Country/Region']!='China')][['Country/Region','1/22/20']]
# Out:
#     Country/Region  1/22/20
# 139          Japan        2
# 143   Korea, South        1
# 207        Taiwan*        1
# 209       Thailand        2
# 225             US        1

# %%
df_cnfmd.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  7/13/20  7/14/20  7/15/20  \
# 0        0        0        0        0  ...    34455    34740    34994
# 1        0        0        0        0  ...     3571     3667     3752
# 2        0        0        0        0  ...    19689    20216    20770
# 3        0        0        0        0  ...      858      861      862
# 4        0        0        0        0  ...      525      541      576
#
#    7/16/20  7/17/20  7/18/20  7/19/20  7/20/20  7/21/20  7/22/20
# ...
